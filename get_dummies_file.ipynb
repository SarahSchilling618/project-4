# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahSchilling618/project-4/blob/main/working_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import psycopg2
from psycopg2 import sql
import pandas as pd

# %%
db_params = {
    'dbname': 'project4',
    'user': 'postgres',
    'password': 'postgres',
    'host': 'localhost',
    'port': '5432'
}

# Establish the connection
conn = psycopg2.connect(**db_params)
cursor = conn.cursor()

# %%
cursor.execute('SELECT * FROM dementia;')
rows = cursor.fetchall()

# %%
colnames = [desc[0] for desc in cursor.description]
df = pd.DataFrame(rows, columns=colnames)

# %%
df
# Out:
#      Diabetic  AlcoholLevel  HeartRate  BloodOxygenLevel  BodyTemperature  \
# 0           1      0.084974         98         96.230743        36.224852
# 1           0      0.016973         78         93.032122        36.183874
# 2           0      0.009000         89         93.566504        37.326321
# 3           0      0.086437         60         93.906510        37.030620
# 4           1      0.150747         67         97.508994        36.062121
# ..        ...           ...        ...               ...              ...
# 995         1      0.081825         87         93.851963        36.495134
# 996         1      0.145249         97         94.522391        36.270804
# 997         1      0.073692         65         98.578388        37.065703
# 998         0      0.037347         71         91.298580        37.037202
# 999         0      0.085969         90         95.522825        36.026748
#
#         Weight  MRI_Delay Prescription  Dosage_in_mg  Age  ...  \
# 0    57.563978  36.421028         None           NaN   60  ...
# 1    56.832335  31.157633  Galantamine          12.0   61  ...
# 2    59.759066  37.640435         None           NaN   69  ...
# 3    58.266471  50.673992    Donepezil          23.0   78  ...
# 4    67.705027  27.810601    Memantine          20.0   77  ...
# ..         ...        ...          ...           ...  ...  ...
# 995  50.380106  42.318663    Donepezil          10.0   88  ...
# 996  94.006484  52.812568         None           NaN   80  ...
# 997  80.088613  13.640229         None           NaN   67  ...
# 998  95.322210  17.445715    Memantine          20.0   62  ...
# 999  57.671455  30.011838         None           NaN   80  ...
#
#      Smoking_Status    APOE_4  Physical_Activity Depression_Status  \
# 0    Current Smoker  Negative          Sedentary                No
# 1     Former Smoker  Positive  Moderate Activity                No
# 2     Former Smoker  Negative  Moderate Activity                No
# 3      Never Smoked  Negative      Mild Activity               Yes
# 4      Never Smoked  Positive      Mild Activity                No
# ..              ...       ...                ...               ...
# 995    Never Smoked  Positive      Mild Activity                No
# 996    Never Smoked  Negative  Moderate Activity                No
# 997    Never Smoked  Positive          Sedentary                No
# 998    Never Smoked  Positive          Sedentary               Yes
# 999    Never Smoked  Positive      Mild Activity                No
#
#     Cognitive_Test_Scores Medication_History      Nutrition_Diet  \
# 0                      10                 No       Low-Carb Diet
# 1                       1                Yes       Low-Carb Diet
# 2                       8                 No  Mediterranean Diet
# 3                       5                Yes       Balanced Diet
# 4                       0                Yes       Low-Carb Diet
# ..                    ...                ...                 ...
# 995                     5                 No       Balanced Diet
# 996                     9                Yes       Low-Carb Diet
# 997                     8                Yes       Balanced Diet
# 998                     2                 No       Low-Carb Diet
# 999                    10                Yes  Mediterranean Diet
#
#     Sleep_Quality  Chronic_Health_Conditions Dementia
# 0            Poor                   Diabetes        0
# 1            Poor              Heart Disease        1
# 2            Poor              Heart Disease        0
# 3            Poor               Hypertension        1
# 4            Good                   Diabetes        1
# ..            ...                        ...      ...
# 995          Poor                   Diabetes        1
# 996          Poor                   Diabetes        0
# 997          Good                   Diabetes        0
# 998          Good                       None        1
# 999          Good              Heart Disease        0
#
# [1000 rows x 24 columns]

# %%
conn.close()

# %%
dummies_df = pd.get_dummies(df)
dummies_df
# Out:
#      Diabetic  AlcoholLevel  HeartRate  BloodOxygenLevel  BodyTemperature  \
# 0           1      0.084974         98         96.230743        36.224852
# 1           0      0.016973         78         93.032122        36.183874
# 2           0      0.009000         89         93.566504        37.326321
# 3           0      0.086437         60         93.906510        37.030620
# 4           1      0.150747         67         97.508994        36.062121
# ..        ...           ...        ...               ...              ...
# 995         1      0.081825         87         93.851963        36.495134
# 996         1      0.145249         97         94.522391        36.270804
# 997         1      0.073692         65         98.578388        37.065703
# 998         0      0.037347         71         91.298580        37.037202
# 999         0      0.085969         90         95.522825        36.026748
#
#         Weight  MRI_Delay  Dosage_in_mg  Age  Cognitive_Test_Scores  ...  \
# 0    57.563978  36.421028           NaN   60                     10  ...
# 1    56.832335  31.157633          12.0   61                      1  ...
# 2    59.759066  37.640435           NaN   69                      8  ...
# 3    58.266471  50.673992          23.0   78                      5  ...
# 4    67.705027  27.810601          20.0   77                      0  ...
# ..         ...        ...           ...  ...                    ...  ...
# 995  50.380106  42.318663          10.0   88                      5  ...
# 996  94.006484  52.812568           NaN   80                      9  ...
# 997  80.088613  13.640229           NaN   67                      8  ...
# 998  95.322210  17.445715          20.0   62                      2  ...
# 999  57.671455  30.011838           NaN   80                     10  ...
#
#      Medication_History_Yes  Nutrition_Diet_Balanced Diet  \
# 0                     False                         False
# 1                      True                         False
# 2                     False                         False
# 3                      True                          True
# 4                      True                         False
# ..                      ...                           ...
# 995                   False                          True
# 996                    True                         False
# 997                    True                          True
# 998                   False                         False
# 999                    True                         False
#
#      Nutrition_Diet_Low-Carb Diet  Nutrition_Diet_Mediterranean Diet  \
# 0                            True                              False
# 1                            True                              False
# 2                           False                               True
# 3                           False                              False
# 4                            True                              False
# ..                            ...                                ...
# 995                         False                              False
# 996                          True                              False
# 997                         False                              False
# 998                          True                              False
# 999                         False                               True
#
#      Sleep_Quality_Good  Sleep_Quality_Poor  \
# 0                 False                True
# 1                 False                True
# 2                 False                True
# 3                 False                True
# 4                  True               False
# ..                  ...                 ...
# 995               False                True
# 996               False                True
# 997                True               False
# 998                True               False
# 999                True               False
#
#      Chronic_Health_Conditions_Diabetes  \
# 0                                  True
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                  True
# ..                                  ...
# 995                                True
# 996                                True
# 997                                True
# 998                               False
# 999                               False
#
#      Chronic_Health_Conditions_Heart Disease  \
# 0                                      False
# 1                                       True
# 2                                       True
# 3                                      False
# 4                                      False
# ..                                       ...
# 995                                    False
# 996                                    False
# 997                                    False
# 998                                    False
# 999                                     True
#
#      Chronic_Health_Conditions_Hypertension  Chronic_Health_Conditions_None
# 0                                     False                           False
# 1                                     False                           False
# 2                                     False                           False
# 3                                      True                           False
# 4                                     False                           False
# ..                                      ...                             ...
# 995                                   False                           False
# 996                                   False                           False
# 997                                   False                           False
# 998                                   False                            True
# 999                                   False                           False
#
# [1000 rows x 46 columns]

# %%
dummies_df.columns
# Out:
# Index(['Diabetic', 'AlcoholLevel', 'HeartRate', 'BloodOxygenLevel',
#        'BodyTemperature', 'Weight', 'MRI_Delay', 'Dosage_in_mg', 'Age',
#        'Cognitive_Test_Scores', 'Dementia', 'Prescription_Donepezil',
#        'Prescription_Galantamine', 'Prescription_Memantine',
#        'Prescription_Rivastigmine', 'Education_Level_Diploma/Degree',
#        'Education_Level_No School', 'Education_Level_Primary School',
#        'Education_Level_Secondary School', 'Dominant_Hand_Left',
#        'Dominant_Hand_Right', 'Gender_Female', 'Gender_Male',
#        'Family_History_No', 'Family_History_Yes',
#        'Smoking_Status_Current Smoker', 'Smoking_Status_Former Smoker',
#        'Smoking_Status_Never Smoked', 'APOE_4_Negative', 'APOE_4_Positive',
#        'Physical_Activity_Mild Activity',
#        'Physical_Activity_Moderate Activity', 'Physical_Activity_Sedentary',
#        'Depression_Status_No', 'Depression_Status_Yes',
#        'Medication_History_No', 'Medication_History_Yes',
#        'Nutrition_Diet_Balanced Diet', 'Nutrition_Diet_Low-Carb Diet',
#        'Nutrition_Diet_Mediterranean Diet', 'Sleep_Quality_Good',
#        'Sleep_Quality_Poor', 'Chronic_Health_Conditions_Diabetes',
#        'Chronic_Health_Conditions_Heart Disease',
#        'Chronic_Health_Conditions_Hypertension',
#        'Chronic_Health_Conditions_None'],
#       dtype='object')

# %%
dummies_df.to_csv('dummies_data.csv')
