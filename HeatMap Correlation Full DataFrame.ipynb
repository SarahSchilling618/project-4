# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Assuming your dataset is named 'data.csv'
# Assuming your dataset is named 'data.csv'
df = pd.read_csv('C://Users//juliu//OneDrive//Desktop//dementia_clean_june.csv')

df
# Out:
#      Unnamed: 0  diabetic  alcohollevel  heartrate  bloodoxygenlevel  \
# 0             0         1      0.003927         69         98.670018
# 1             1         0      0.021376         84         93.794230
# 2             2         1      0.082257         87         90.075250
# 3             3         1      0.101423         77         94.872009
# 4             4         0      0.165444         98         97.256318
# ..          ...       ...           ...        ...               ...
# 995         995         0      0.175874         77         93.435744
# 996         996         1      0.078675         93         91.500005
# 997         997         0      0.052985         74         95.537917
# 998         998         1      0.120131         63         97.799862
# 999         999         1      0.054990         93         91.949669
#
#      bodytemperature     weight  mri_delay  prescription  dosage_in_mg  ...  \
# ...

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'diabetic', 'alcohollevel', 'heartrate',
#        'bloodoxygenlevel', 'bodytemperature', 'weight', 'mri_delay',
#        'prescription', 'dosage_in_mg', 'age', 'education_level',
#        'dominant_hand', 'gender', 'family_history', 'smoking_status', 'apoe_4',
#        'physical_activity', 'depression_status', 'cognitive_test_scores',
#        'medication_history', 'nutrition_diet', 'sleep_quality',
#        'chronic_health_conditions', 'dementia'],
#       dtype='object')

# %%
columns_to_drop = ['Unnamed: 0', 'smoking_status','prescription', 'dosage_in_mg', 'education_level', 'dominant_hand', 'gender', 'family_history'] # List of columns to drop
df = df.drop(columns_to_drop, axis=1)
df
# Out:
#      diabetic  alcohollevel  heartrate  bloodoxygenlevel  bodytemperature  \
# 0           1      0.003927         69         98.670018        36.903036
# 1           0      0.021376         84         93.794230        36.512407
# 2           1      0.082257         87         90.075250        37.235479
# 3           1      0.101423         77         94.872009        37.093841
# 4           0      0.165444         98         97.256318        37.356031
# ..        ...           ...        ...               ...              ...
# 995         0      0.175874         77         93.435744        37.042413
# 996         1      0.078675         93         91.500005        36.533927
# 997         0      0.052985         74         95.537917        36.533912
# 998         1      0.120131         63         97.799862        37.315487
# 999         1      0.054990         93         91.949669        37.242654
#
#         weight  mri_delay  age  apoe_4  physical_activity  depression_status  \
# ...

# %%
corr_matrix = df.corr()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()
